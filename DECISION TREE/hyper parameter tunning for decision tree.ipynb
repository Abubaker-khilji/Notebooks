# %%
import numpy as np
import pandas as pd

# %%
file = pd.read_csv("Social_Network_Ads.csv")

# %%
file.head(5)
file['Gender'].replace({'Male':0,'Female':1},inplace=True)
X=file.iloc[:,1:4].values
y=file.iloc[:,-1].values

# %%
from sklearn.preprocessing import StandardScaler
scaler  = StandardScaler()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2 , random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.775

# %%
param_dist={
    "criterion":["gini","entropy"],
    "max_depth":[1,2,3,4,5,6,7,None]
}

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(clf,param_grid=param_dist,cv=10, n_jobs=-1)

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 2, 3, 4, 5, 6, 7, None]})

# %%
grid.best_score_
# Out:
# 0.91875

# %%
grid.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
grid.cv_results_
# Out:
# {'mean_fit_time': array([0.00239766, 0.00229793, 0.00264869, 0.00215402, 0.0029496 ,
#         0.00219834, 0.00200353, 0.00204973, 0.00195224, 0.00219841,
#         0.00310113, 0.00229845, 0.00209897, 0.00199873, 0.00220752,
#         0.00305159]),
#  'std_fit_time': array([0.0010188 , 0.00064012, 0.00083805, 0.00077426, 0.00119165,
#         0.00060014, 0.00045653, 0.00072459, 0.0006481 , 0.00074742,
#         0.00295304, 0.00045773, 0.00053838, 0.00077485, 0.00117951,
#         0.00237777]),
#  'mean_score_time': array([0.00240159, 0.00199893, 0.00225074, 0.0018486 , 0.0023494 ,
#         0.00149963, 0.00159695, 0.00180228, 0.0017971 , 0.00140164,
#         0.00200119, 0.00139918, 0.00149965, 0.00180192, 0.00219562,
#         0.00130324]),
#  'std_score_time': array([0.00143041, 0.00089372, 0.00163049, 0.00099986, 0.00054834,
#         0.00049961, 0.00066235, 0.00071689, 0.00059587, 0.00049273,
#         0.0010016 , 0.00048986, 0.0009222 , 0.00117159, 0.00231504,
#         0.00046375]),
#  'param_criterion': masked_array(data=['gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[1, 2, 3, 4, 5, 6, 7, None, 1, 2, 3, 4, 5, 6, 7, None],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'criterion': 'gini', 'max_depth': 1},
#   {'criterion': 'gini', 'max_depth': 2},
#   {'criterion': 'gini', 'max_depth': 3},
#   {'criterion': 'gini', 'max_depth': 4},
#   {'criterion': 'gini', 'max_depth': 5},
#   {'criterion': 'gini', 'max_depth': 6},
#   {'criterion': 'gini', 'max_depth': 7},
#   {'criterion': 'gini', 'max_depth': None},
#   {'criterion': 'entropy', 'max_depth': 1},
#   {'criterion': 'entropy', 'max_depth': 2},
#   {'criterion': 'entropy', 'max_depth': 3},
#   {'criterion': 'entropy', 'max_depth': 4},
#   {'criterion': 'entropy', 'max_depth': 5},
#   {'criterion': 'entropy', 'max_depth': 6},
#   {'criterion': 'entropy', 'max_depth': 7},
#   {'criterion': 'entropy', 'max_depth': None}],
#  'split0_test_score': array([0.875  , 0.8125 , 0.78125, 0.78125, 0.78125, 0.90625, 0.78125,
#         0.84375, 0.875  , 0.8125 , 0.8125 , 0.8125 , 0.78125, 0.84375,
#         0.8125 , 0.84375]),
#  'split1_test_score': array([0.84375, 0.875  , 0.875  , 0.875  , 0.84375, 0.875  , 0.84375,
#         0.8125 , 0.84375, 0.875  , 0.875  , 0.875  , 0.84375, 0.875  ,
#         0.875  , 0.8125 ]),
#  'split2_test_score': array([0.8125 , 0.90625, 0.90625, 0.90625, 0.9375 , 0.90625, 0.90625,
#         0.90625, 0.8125 , 0.90625, 0.90625, 0.875  , 0.875  , 0.9375 ,
#         0.9375 , 0.90625]),
#  'split3_test_score': array([0.875  , 0.96875, 0.96875, 0.96875, 0.96875, 0.9375 , 0.96875,
#         0.875  , 0.875  , 0.96875, 0.96875, 0.96875, 0.96875, 0.96875,
#         0.96875, 0.96875]),
#  'split4_test_score': array([0.8125 , 0.96875, 0.96875, 0.96875, 0.9375 , 0.9375 , 0.9375 ,
#         0.96875, 0.8125 , 0.96875, 0.96875, 0.9375 , 0.9375 , 0.9375 ,
#         0.9375 , 0.96875]),
#  'split5_test_score': array([0.84375, 0.90625, 0.90625, 0.90625, 0.90625, 0.875  , 0.8125 ,
#         0.8125 , 0.84375, 0.90625, 0.90625, 0.90625, 0.90625, 0.875  ,
#         0.8125 , 0.78125]),
#  'split6_test_score': array([0.78125, 0.96875, 0.96875, 0.9375 , 0.90625, 0.90625, 0.90625,
#         0.90625, 0.78125, 0.96875, 0.96875, 0.9375 , 0.875  , 0.90625,
#         0.875  , 0.875  ]),
#  'split7_test_score': array([0.90625, 1.     , 0.96875, 1.     , 1.     , 0.96875, 0.96875,
#         0.90625, 0.90625, 1.     , 1.     , 0.96875, 1.     , 1.     ,
#         1.     , 1.     ]),
#  'split8_test_score': array([0.78125, 0.875  , 0.875  , 0.875  , 0.875  , 0.84375, 0.875  ,
#         0.875  , 0.78125, 0.875  , 0.875  , 0.84375, 0.875  , 0.875  ,
#         0.875  , 0.875  ]),
#  'split9_test_score': array([0.875  , 0.90625, 0.90625, 0.90625, 0.84375, 0.84375, 0.875  ,
#         0.90625, 0.875  , 0.90625, 0.90625, 0.875  , 0.8125 , 0.84375,
#         0.875  , 0.90625]),
#  'mean_test_score': array([0.840625, 0.91875 , 0.9125  , 0.9125  , 0.9     , 0.9     ,
#         0.8875  , 0.88125 , 0.840625, 0.91875 , 0.91875 , 0.9     ,
#         0.8875  , 0.90625 , 0.896875, 0.89375 ]),
#  'std_test_score': array([0.040625  , 0.05448624, 0.0572822 , 0.05896238, 0.06218671,
#         0.03903124, 0.0596212 , 0.04592793, 0.040625  , 0.05448624,
#         0.05448624, 0.05      , 0.06434769, 0.05038911, 0.059375  ,
#         0.06731456]),
#  'rank_test_score': array([15,  1,  4,  4,  7,  7, 12, 14, 15,  1,  1,  7, 12,  6, 10, 11])}

# %%
grid.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 2}
