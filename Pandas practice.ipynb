# %%
import pandas as pd

# %% [markdown]
# # aik file ki dataset pandas think it as dataframe aur os column say data aur row say data is known as series

# %% [markdown]
# ### series may do chez hoti index and value index unique hona mangta and value can be same no problem

# %%
file=pd.read_csv("WorldCupMatches.csv")

# %%
file.dtypes
# Out:
# Year                    float64
# Datetime                 object
# Stage                    object
# Stadium                  object
# City                     object
# Home Team Name           object
# Home Team Goals         float64
# Away Team Goals         float64
# Away Team Name           object
# Win conditions           object
# Attendance              float64
# Half-time Home Goals    float64
# Half-time Away Goals    float64
# Referee                  object
# Assistant 1              object
# Assistant 2              object
# RoundID                 float64
# MatchID                 float64
# Home Team Initials       object
# Away Team Initials       object
# dtype: object

# %%
file.head(5)
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
file.shape #this is not function it is attribute so not using brackets
# Out:
# (4572, 20)

# %%
file.info() #info with no bracket is aslo availble
            #pandas sting ko object bolta  #imppoint recuse memory foot print is data scientist job
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    float64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    float64
#  7   Away Team Goals       852 non-null    float64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    float64
#  12  Half-time Away Goals  852 non-null    float64
#  13  Referee               852 non-null    object
# ...

# %%
file.describe()
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# ...

# %% [markdown]
# # only coloumn ya row fetch krnay ka tarika

# %%
file['Attendance'].shape #for one coloumn
# Out:
# (4572,)

# %%
file[['Home Team Name','Away Team Name','Stadium']] #for multiple column use list inside square brackets
# Out:
#      Home Team Name Away Team Name         Stadium
# 0            France         Mexico         Pocitos
# 1               USA        Belgium  Parque Central
# 2        Yugoslavia         Brazil  Parque Central
# 3           Romania           Peru         Pocitos
# 4         Argentina         France  Parque Central
# ...             ...            ...             ...
# 4567            NaN            NaN             NaN
# 4568            NaN            NaN             NaN
# 4569            NaN            NaN             NaN
# 4570            NaN            NaN             NaN
# 4571            NaN            NaN             NaN
#
# [4572 rows x 3 columns]

# %% [markdown]
# # for multiple rows

# %%
file.iloc[1:3]
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 1                    18346.0                   2.0                   0.0
# 2                    24059.0                   2.0                   0.0
#
#                Referee               Assistant 1            Assistant 2  \
# 1    MACIAS Jose (ARG)  MATEUCCI Francisco (URU)  WARNKEN Alberto (CHI)
# 2  TEJADA Anibal (URU)   VALLARINO Ricardo (URU)    BALWAY Thomas (FRA)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# ...

# %%
file.iloc[1:11:2] #first coloumn say laykur eleven tuk rows fetch kro but hur roe k baad five jumps kro
# Out:
#      Year              Datetime    Stage             Stadium         City  \
# 1  1930.0  13 Jul 1930 - 15:00   Group 4      Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3             Pocitos  Montevideo
# 5  1930.0  16 Jul 1930 - 14:45   Group 1      Parque Central  Montevideo
# 7  1930.0  17 Jul 1930 - 14:45   Group 4      Parque Central  Montevideo
# 9  1930.0  19 Jul 1930 - 12:50   Group 1  Estadio Centenario  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 1            USA              3.0              0.0        Belgium
# 3        Romania              3.0              1.0           Peru
# 5          Chile              3.0              0.0         Mexico
# 7            USA              3.0              0.0       Paraguay
# 9          Chile              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# ...

# %%
file.iloc[[3,7,9]] #this is fancy indexing with double bracket or list inside of it
# Out:
#      Year              Datetime    Stage             Stadium         City  \
# 3  1930.0  14 Jul 1930 - 14:50   Group 3             Pocitos  Montevideo
# 7  1930.0  17 Jul 1930 - 14:45   Group 4      Parque Central  Montevideo
# 9  1930.0  19 Jul 1930 - 12:50   Group 1  Estadio Centenario  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 3        Romania              3.0              1.0           Peru
# 7            USA              3.0              0.0       Paraguay
# 9          Chile              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3                     2549.0                   1.0                   0.0
# 7                    18306.0                   2.0                   0.0
# 9                     2000.0                   0.0                   0.0
#
#                  Referee              Assistant 1               Assistant 2  \
# ...

# %%
file['Home Team Name']=='France'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4567    False
# 4568    False
# 4569    False
# 4570    False
# 4571    False
# Name: Home Team Name, Length: 4572, dtype: bool

# %%
mask=file['Home Team Name']=='France'
file[mask]
# Out:
#        Year              Datetime                  Stage  \
# 0    1930.0  13 Jul 1930 - 15:00                 Group 1
# 37   1938.0  05 Jun 1938 - 17:00             First round
# 85   1954.0  19 Jun 1954 - 17:10                 Group 1
# 105  1958.0  08 Jun 1958 - 19:00                 Group 2
# 122  1958.0  15 Jun 1958 - 19:00                 Group 2
# 131  1958.0  19 Jun 1958 - 19:00          Quarter-finals
# 134  1958.0  28 Jun 1958 - 17:00   Match for third place
# 172  1966.0  13 Jul 1966 - 19:30                 Group 1
# 286  1978.0  10 Jun 1978 - 15:10                 Group 1
# 330  1982.0  21 Jun 1982 - 17:15                 Group 4
# 339  1982.0  24 Jun 1982 - 17:15                 Group 4
# 352  1982.0  04 Jul 1982 - 17:15                 Group 4
# 373  1986.0  05 Jun 1986 - 12:00                 Group C
# 408  1986.0  25 Jun 1986 - 12:00             Semi-finals
# 410  1986.0  28 Jun 1986 - 12:00   Match for third place
# ...

# %%
def get_home_team_name(HomeTeamName):
    mask=file['Home Team Name']==HomeTeamName
    file[mask]
    return file[mask].shape[0]

# %%
file[mask]
# Out:
#        Year              Datetime                  Stage  \
# 0    1930.0  13 Jul 1930 - 15:00                 Group 1
# 37   1938.0  05 Jun 1938 - 17:00             First round
# 85   1954.0  19 Jun 1954 - 17:10                 Group 1
# 105  1958.0  08 Jun 1958 - 19:00                 Group 2
# 122  1958.0  15 Jun 1958 - 19:00                 Group 2
# 131  1958.0  19 Jun 1958 - 19:00          Quarter-finals
# 134  1958.0  28 Jun 1958 - 17:00   Match for third place
# 172  1966.0  13 Jul 1966 - 19:30                 Group 1
# 286  1978.0  10 Jun 1978 - 15:10                 Group 1
# 330  1982.0  21 Jun 1982 - 17:15                 Group 4
# 339  1982.0  24 Jun 1982 - 17:15                 Group 4
# 352  1982.0  04 Jul 1982 - 17:15                 Group 4
# 373  1986.0  05 Jun 1986 - 12:00                 Group C
# 408  1986.0  25 Jun 1986 - 12:00             Semi-finals
# 410  1986.0  28 Jun 1986 - 12:00   Match for third place
# ...

# %%
get_home_team_name("Germany")
# Out:
# 34

# %%
file['Home Team Goals']>'1980' #filteration data frame
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19712\1595950772.py in <module>
# ----> 1 file['Home Team Goals']>'1980' #filteration data frame
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5621
#    5622         with np.errstate(all="ignore"):
# ...

# %%
file['Year']=file.Year.astype(float)

# %%
file.dtypes
# Out:
# Year                    float64
# Datetime                 object
# Stage                    object
# Stadium                  object
# City                     object
# Home Team Name           object
# Home Team Goals         float64
# Away Team Goals         float64
# Away Team Name           object
# Win conditions           object
# Attendance              float64
# Half-time Home Goals    float64
# Half-time Away Goals    float64
# Referee                  object
# Assistant 1              object
# Assistant 2              object
# RoundID                 float64
# MatchID                 float64
# Home Team Initials       object
# Away Team Initials       object
# dtype: object

# %%
file['Referee'].value_counts() #kisi coloumn may koi Value kitni dfa appear hoi hai
# Out:
# Ravshan IRMATOV (UZB)             10
# RODRIGUEZ Marco (MEX)              8
# LARRIONDA Jorge (URU)              8
# ARCHUNDIA Benito (MEX)             8
# QUINIOU Joel (FRA)                 8
#                                   ..
# LABO REVOREDO Enrique (PER)        1
# ITHURRALDE Arturo Andres (ARG)     1
# DWOMOH Benjamin (GHA)              1
# ESCHWEILER Walter (GER)            1
# Bakary GASSAMA (GAM)               1
# Name: Referee, Length: 366, dtype: int64

# %%
import matplotlib.pyplot as ply

# %%
file['Stadium'].value_counts().head().plot(kind = 'barh') #barchart use for categorical value
# Out:
# <AxesSubplot:>

# %%
file['Win conditions'].value_counts().tail().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Win conditions'>

# %%
file['Attendance'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
file['Home Team Name'].value_counts() + file['Away Team Name'].value_counts()
# Out:
# Algeria                       14.0
# Angola                         3.0
# Argentina                     81.0
# Australia                     13.0
# Austria                       29.0
#                               ...
# rn">Bosnia and Herzegovina     3.0
# rn">Republic of Ireland       13.0
# rn">Serbia and Montenegro      3.0
# rn">Trinidad and Tobago        3.0
# rn">United Arab Emirates       3.0
# Length: 83, dtype: float64

# %%
file['Away Team Name'].value_counts()
# Out:
# Mexico               38
# France               30
# Spain                29
# Argentina            27
# England              27
#                      ..
# Dutch East Indies     1
# Togo                  1
# Cuba                  1
# Zaire                 1
# Iraq                  1
# Name: Away Team Name, Length: 83, dtype: int64

# %%
file.drop_duplicates(subset=['Stadium','Away Team Name'])
# Out:
#        Year              Datetime           Stage             Stadium  \
# 0    1930.0  13 Jul 1930 - 15:00          Group 1             Pocitos
# 1    1930.0  13 Jul 1930 - 15:00          Group 4      Parque Central
# 2    1930.0  14 Jul 1930 - 12:45          Group 2      Parque Central
# 3    1930.0  14 Jul 1930 - 14:50          Group 3             Pocitos
# 4    1930.0  15 Jul 1930 - 16:00          Group 1      Parque Central
# ..      ...                   ...             ...                 ...
# 831  2014.0  05 Jul 2014 - 13:00   Quarter-finals    Estadio Nacional
# 833  2014.0  29 Jun 2014 - 17:00      Round of 16    Arena Pernambuco
# 834  2014.0  01 Jul 2014 - 13:00      Round of 16  Arena de Sao Paulo
# 835  2014.0  01 Jul 2014 - 17:00      Round of 16    Arena Fonte Nova
# 852     NaN                   NaN             NaN                 NaN
#
#             City Home Team Name  Home Team Goals  Away Team Goals  \
# ...

# %%
file.groupby('Stadium')

# %%
stadium = file.groupby('Stadium')

# %%
len(file)
# Out:
# 4572

# %%
len(stadium)
# Out:
# 181

# %%
type(stadium)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
stadium.first()
# Out:
#                     Year              Datetime    Stage       City  \
# Stadium
# Arena Amazonia    2014.0  14 Jun 2014 - 18:00   Group D    Manaus
# Arena Fonte Nova  2014.0  13 Jun 2014 - 16:00   Group B  Salvador
# Arena Pantanal    2014.0  13 Jun 2014 - 18:00   Group B    Cuiaba
# Arena Pernambuco  2014.0  14 Jun 2014 - 22:00   Group C    Recife
# Arena da Baixada  2014.0  16 Jun 2014 - 16:00   Group F  Curitiba
# ...                  ...                   ...      ...        ...
# Wankdorf Stadium  1954.0  16 Jun 1954 - 18:00   Group 3     Berne
# Wembley Stadium   1966.0  11 Jul 1966 - 19:30   Group 1    London
# Westfalenstadion  1974.0  14 Jun 1974 - 19:30   Group 2  Dortmund
# White City        1966.0  15 Jul 1966 - 19:30   Group 1    London
# Zentralstadion    2006.0  11 Jun 2006 - 15:00   Group C   Leipzig
#
#                              Home Team Name  Home Team Goals  Away Team Goals  \
# Stadium
# ...

# %%
stadium.groups
# Out:
# {'Arena Amazonia': [778, 791, 803, 814], 'Arena Fonte Nova': [774, 783, 796, 813, 830, 835, 843, 847], 'Arena Pantanal': [775, 788, 800, 810], 'Arena Pernambuco': [779, 795, 807, 816, 833, 839], 'Arena da Baixada': [784, 797, 804, 819], 'Arena de Sao Paulo': [772, 793, 805, 818, 829, 834, 842, 849], 'Arosvallen': [106, 112], 'Arroyito - Estadio Dr. Lisandro de la Torre': [272, 279, 287, 297, 301, 305], 'Ayresome Park': [171, 179, 187], 'Benito Villamarin': [322, 337], 'Bombonera - Estadio Nemesio Diez': [369, 381, 388], 'Busan Asiad Main Stadium': [585, 593, 599], 'Camp Nou': [308, 345, 349, 353, 356], 'Cape Town Stadium': [709, 718, 730, 737, 751, 763, 766, 768], 'Carlos Dittborn': [136, 140, 144, 148, 152, 156, 160], 'Carlos Tartiere': [317, 329, 338], 'Cavee Verte': [41], 'Charmilles': [77, 85, 88, 95], 'Citrus Bowl': [469, 481, 484, 496, 504], 'Comunale': [416, 428, 441, 456], 'Comunale di Cornaredo': [90], 'Cotton Bowl': [464, 475, 490, 499, 502, 509], 'Cuauhtemoc': [201, 208, 2
# ...

# %%
#file.iloc[778 , :]
stadium.get_group('Arena Fonte Nova') #saray stadium naikalo arena fonte nova k
# Out:
#        Year              Datetime           Stage           Stadium  \
# 774  2014.0  13 Jun 2014 - 16:00          Group B  Arena Fonte Nova
# 783  2014.0  16 Jun 2014 - 13:00          Group G  Arena Fonte Nova
# 796  2014.0  20 Jun 2014 - 16:00          Group E  Arena Fonte Nova
# 813  2014.0  25 Jun 2014 - 13:00          Group F  Arena Fonte Nova
# 830  2014.0  05 Jul 2014 - 17:00   Quarter-finals  Arena Fonte Nova
# 835  2014.0  01 Jul 2014 - 17:00      Round of 16  Arena Fonte Nova
# 843  2014.0  01 Jul 2014 - 17:00      Round of 16  Arena Fonte Nova
# 847  2014.0  05 Jul 2014 - 17:00   Quarter-finals  Arena Fonte Nova
#
#           City              Home Team Name  Home Team Goals  Away Team Goals  \
# 774  Salvador                        Spain              1.0              5.0
# 783  Salvador                      Germany              4.0              0.0
# 796  Salvador                  Switzerland              2.0              5.0
# ...

# %%
stadium.mean()
# Out:
#                     Year  Home Team Goals  Away Team Goals    Attendance  \
# Stadium
# Arena Amazonia    2014.0         0.750000         2.750000  40056.750000
# Arena Fonte Nova  2014.0         1.750000         1.625000  50385.000000
# Arena Pantanal    2014.0         1.500000         1.500000  39679.250000
# Arena Pernambuco  2014.0         0.833333         1.333333  41020.666667
# Arena da Baixada  2014.0         0.500000         1.500000  39247.750000
# ...                  ...              ...              ...           ...
# Wankdorf Stadium  1954.0         3.000000         1.000000  38900.000000
# Wembley Stadium   1966.0         1.555556         0.555556  86448.222222
# Westfalenstadion  1974.0         0.750000         1.500000  46925.000000
# White City        1966.0         2.000000         1.000000  45662.000000
# Zentralstadion    2006.0         1.600000         0.800000  42000.000000
#
#                   Half-time Home Goals  Half-time Away Goals       RoundID  \
# ...

# %%
players = pd.read_csv('EPL_20_21.csv')
players.head(1)
# Out:
#           Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0  Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# 0                  1  0.21  0.24             2          0

# %%
players[['Club','Matches']]
# Out:
#                  Club  Matches
# 0             Chelsea       36
# 1             Chelsea       31
# 2             Chelsea       35
# 3             Chelsea       27
# 4             Chelsea       32
# ..                ...      ...
# 527  Sheffield United       11
# 528  Sheffield United        2
# 529  Sheffield United        1
# 530  Sheffield United        1
# 531  Sheffield United        1
#
# [532 rows x 2 columns]

# %%
players.groupby('Nationality')

# %%
goal=players.groupby('Nationality')

# %%
goal.get
# Out:
#           Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 4  Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 4      1        2              1987                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# 4                  0  0.06  0.12             3          0

# %%
file.shape
# Out:
# (4572, 20)

# %%
file.dropna(how='all').shape
# Out:
# (852, 20)

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.Dataframe(data ,index='Label')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13164\2749235134.py in <module>
#       6 labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
#       7
# ----> 8 df = pd.Dataframe(data ,index='Label')
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     259         return _SparseArray
#     260
# --> 261     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     262
#     263
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
import numpy as np

np.__version__
# Out:
# '1.21.5'

# %%
pd.__version__
# Out:
# '1.4.4'
